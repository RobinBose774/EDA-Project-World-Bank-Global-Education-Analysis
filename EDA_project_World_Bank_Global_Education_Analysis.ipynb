# %% [markdown]
# <a href="https://colab.research.google.com/github/RobinBose774/EDA-Project-World-Bank-Global-Education-Analysis/blob/main/EDA_project_World_Bank_Global_Education_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name    - World Bank Global Education Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA Capstone project
# ##### **Contribution**    - Individual / Robin Bose

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The World Bank EdStats (Education Statistics) portal is your comprehensive data and analysis source for key topics in education such as access, completion, learning, expenditures, policy, and equity. Data sources include administrative country data from UIS; international learning assessments (PISA, TIMSS, PIRLS, PIAAC, and EGRA) and three regional learning assessments (SACMEQ, PASEC, LLECE); World Bank databases, household surveys such as LSMS, DHS, MICS surveys. It includes World Bank Education Projects Database classified by activities, components, and sub-sectors of all World Bank Education Projects since 1998.
#
# This is a dataset hosted by the World Bank. The organization has an open data platform found here and they update their information according the amount of data that is brought in. Explore the World Bank using Kaggle and all of the data sources available through the World Bank organization page!
#
# I analysed the edstatsdata from there databank and came up with some important insights. From cleaning the data to extracting valuable information, a step by step procedure is explained at every junction. I tried to keep it simple, aesthetically pleasing and understandable.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Github Link :- https://github.com/RobinBose774/EDA-Project-World-Bank-Global-Education-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In this project we are going to analyze the World Bank EdStats Data in order to find out valuable insights and use those insights to suggest some policies to bring out better learning outcomes for different countries

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Policymakers in different countries who are working to improve student learning often find themselves flying blind. They see the budget that goes into education and (sometimes) the learning that students come out with, but they lack information on the crucial factors in between— the practices, policies, and politics—that drive those learning outcomes. using the world bank global education dataset, i aim to draw conclusions which will help in policy making.
#
# How to improve outcome of "expenditure on education" by government policies.
#
# The World Bank EdStats All Indicator Query holds over 4,000 internationally comparable indicators that describe education access, progression, completion, literacy, teachers, population, and expenditures.The indicators cover the education cycle from pre-primary to vocational and tertiary education and also holds learning outcome data from international and regional learning assessments (e.g. PISA, TIMSS, PIRLS), equity data from household surveys, and projection/attainment data. so we will use this data to carry out analysis to find out impacts of different factors on learning outcomes and how to improve these inputs so as to maximise the output

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/capston project/world bank global education analysis/data WBGE/'
ed_stats_country_series_df = pd.read_csv(file_path + 'EdStatsCountry-Series.csv')
ed_stats_country = pd.read_csv(file_path + 'EdStatsCountry.csv')
ed_stats_data = pd.read_csv(file_path + 'EdStatsData.csv')
ed_stats_footnote = pd.read_csv(file_path + 'EdStatsFootNote.csv')
ed_stats_Series = pd.read_csv(file_path + 'EdStatsSeries.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ed_stats_country_series_df.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
# 4         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
ed_stats_country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
ed_stats_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
ed_stats_footnote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
ed_stats_Series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# %%
print(ed_stats_country_series_df.columns)
print(ed_stats_country_series_df.shape)
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')
# (613, 4)

# %%
print(ed_stats_country.columns)
print(ed_stats_country.shape)
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')
# (241, 32)

# %%
print(ed_stats_data.columns)
print(ed_stats_data.shape)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')
# (886930, 70)

# %%
print(ed_stats_footnote.columns)
print(ed_stats_footnote.shape)
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')
# (643638, 5)

# %%
print(ed_stats_Series.columns)
print(ed_stats_Series.shape)
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')
# (3665, 21)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

# %%
ed_stats_country_series_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  613 non-null    object
#  1   SeriesCode   613 non-null    object
#  2   DESCRIPTION  613 non-null    object
#  3   Unnamed: 3   0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 19.3+ KB

# %%
ed_stats_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
ed_stats_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
ed_stats_footnote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643638 entries, 0 to 643637
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CountryCode  643638 non-null  object
#  1   SeriesCode   643638 non-null  object
#  2   Year         643638 non-null  object
#  3   DESCRIPTION  643638 non-null  object
#  4   Unnamed: 4   0 non-null       float64
# dtypes: float64(1), object(4)
# memory usage: 24.6+ MB

# %%
ed_stats_Series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665 entries, 0 to 3664
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Series Code                          3665 non-null   object
#  1   Topic                                3665 non-null   object
#  2   Indicator Name                       3665 non-null   object
#  3   Short definition                     2156 non-null   object
#  4   Long definition                      3665 non-null   object
#  5   Unit of measure                      0 non-null      float64
#  6   Periodicity                          99 non-null     object
#  7   Base Period                          314 non-null    object
#  8   Other notes                          552 non-null    object
#  9   Aggregation method                   47 non-null     object
#  10  Limitations and exceptions           14 non-null     object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ed_stats_country_series_df['CountryCode'].value_counts()
# Out:
# MDA    18
# GEO    18
# CYP    12
# SRB    12
# MUS    12
#        ..
# GRL     2
# GTM     2
# GUM     2
# HKG     2
# ZWE     2
# Name: CountryCode, Length: 211, dtype: int64

# %%
# ed_stats_country.groupby('Country Code')['Long Name'].count()
ed_stats_country['Country Code'].value_counts()
# Out:
# ABW    1
# LCA    1
# MRT    1
# MUS    1
# MWI    1
#       ..
# GRL    1
# GTM    1
# GUM    1
# GUY    1
# ZWE    1
# Name: Country Code, Length: 241, dtype: int64

# %%
# ed_stats_data.groupby('Country Code')['Country Name'].count()
ed_stats_data['Country Code'].value_counts()
# Out:
# ARB    3665
# PRT    3665
# FSM    3665
# MDA    3665
# MCO    3665
#        ...
# GNQ    3665
# ERI    3665
# EST    3665
# ETH    3665
# ZWE    3665
# Name: Country Code, Length: 242, dtype: int64

# %%
# ed_stats_footnote.groupby('CountryCode')['SeriesCode'].count()
ed_stats_footnote['CountryCode'].value_counts()
# Out:
# LIC    7320
# CYP    7183
# LDC    6481
# SSA    6389
# SSF    6336
#        ...
# IMN      32
# CUW      23
# XKX      12
# MNP       4
# FRO       2
# Name: CountryCode, Length: 239, dtype: int64

# %%
ed_stats_Series['Series Code'].value_counts()
# Out:
# BAR.NOED.1519.FE.ZS            1
# SP.POP.0710.FE.UN              1
# SP.POP.0710.TO.UN              1
# SP.POP.0711.FE.UN              1
# SP.POP.0711.MA.UN              1
#                               ..
# LO.PASEC.MAT5.LO.MA            1
# LO.PASEC.MAT5.MA               1
# LO.PASEC.REA.2                 1
# LO.PASEC.REA.2.FE              1
# XGDP.56.FSGOV.FDINSTADM.FFD    1
# Name: Series Code, Length: 3665, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ed_stats_country_series_df.isnull().sum()
# Out:
# CountryCode      0
# SeriesCode       0
# DESCRIPTION      0
# Unnamed: 3     613
# dtype: int64

# %%
ed_stats_country.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           3
# Currency Unit                                         26
# Special Notes                                         96
# Region                                                27
# Income Group                                          27
# WB-2 code                                              1
# National accounts base year                           36
# National accounts reference year                     209
# SNA price valuation                                   44
# Lending category                                      97
# Other groups                                         183
# System of National Accounts                           26
# ...

# %%
ed_stats_data.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Unnamed: 69       886930
# Length: 70, dtype: int64

# %%
ed_stats_footnote.isnull().sum()
# Out:
# CountryCode         0
# SeriesCode          0
# Year                0
# DESCRIPTION         0
# Unnamed: 4     643638
# dtype: int64

# %%
ed_stats_Series.isnull().sum()
# Out:
# Series Code                               0
# Topic                                     0
# Indicator Name                            0
# Short definition                       1509
# Long definition                           0
# Unit of measure                        3665
# Periodicity                            3566
# Base Period                            3351
# Other notes                            3113
# Aggregation method                     3618
# Limitations and exceptions             3651
# Notes from original source             3665
# General comments                       3651
# Source                                    0
# Statistical concept and methodology    3642
# Development relevance                  3662
# Related source links                   3450
# Other web links                        3665
# Related indicators                     3665
# License Type                           3665
# Unnamed: 20                            3665
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
plt.figure(figsize=(10,6))

# %%
msno.bar(ed_stats_country_series_df, figsize=(5,2))
# Out:
# <Axes: >

# %%
msno.bar(ed_stats_country, figsize = (15,5))
# Out:
# <Axes: >

# %%
msno.bar(ed_stats_data, figsize=(25,15))
# Out:
# <Axes: >

# %%
msno.bar(ed_stats_footnote, figsize = (15,5))
# Out:
# <Axes: >

# %%
msno.bar(ed_stats_Series, figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **From the above exercise, I have come to the following colclusions about our datasets:-.**
#
# **EdStatsData:-** This file contains Education Statistics data (from year 1970 to 2100) of all the countries that are World Bank members and this data is dependent on various indicators that resembles various factors that affect the overall Education growth and development of the country. These indicators can be access, availabilty, teachers, expenditures, population, lieracy, assessments etc.
#
# **EdStatsCountry:-** This file contains information from census and surveys across various departments, segregated in a country-wise manner.
#
# **EdStatsCountry-Series:-** This file contains the Series Code for various indicators, as well as the Data sources from which they have been derived.
#
# **EdStatsFootNote:-** This file contains year wise indicator names along with their respective descrption. It tells us the nature of the indicators, if its and estimate value or a percentage distribution etc.
#
# **EdStatsSeries:-** This file contains regional learning assessments data(e.g. PISA, TIMSS, PIRLS), equity data from household surveys, and projection/attainment data.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ed_stats_country_series_df.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')

# %%
ed_stats_country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
ed_stats_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
ed_stats_footnote.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')

# %%
ed_stats_Series.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
# Dataset Describe
ed_stats_country_series_df.describe()
# Out:
#        Unnamed: 3
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
ed_stats_country.describe()
# Out:
#        National accounts reference year  Latest industrial data  \
# count                          32.00000              107.000000
# mean                         2001.53125             2008.102804
# std                             5.24856                2.616834
# min                          1987.00000             2000.000000
# 25%                          1996.75000             2007.500000
# 50%                          2002.00000             2009.000000
# 75%                          2005.00000             2010.000000
# max                          2012.00000             2010.000000
#
#        Latest trade data  Unnamed: 31
# count         185.000000          0.0
# mean         2010.994595          NaN
# std             2.569675          NaN
# min          1995.000000          NaN
# 25%          2011.000000          NaN
# 50%          2012.000000          NaN
# 75%          2012.000000          NaN
# max          2012.000000          NaN

# %%
ed_stats_data.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
ed_stats_footnote.describe()
# Out:
#        Unnamed: 4
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
ed_stats_Series.describe()
# Out:
#        Unit of measure  Notes from original source  Other web links  \
# count              0.0                         0.0              0.0
# mean               NaN                         NaN              NaN
# std                NaN                         NaN              NaN
# min                NaN                         NaN              NaN
# 25%                NaN                         NaN              NaN
# 50%                NaN                         NaN              NaN
# 75%                NaN                         NaN              NaN
# max                NaN                         NaN              NaN
#
#        Related indicators  License Type  Unnamed: 20
# count                 0.0           0.0          0.0
# mean                  NaN           NaN          NaN
# std                   NaN           NaN          NaN
# min                   NaN           NaN          NaN
# 25%                   NaN           NaN          NaN
# ...

# %% [markdown]
# ## **Variables Description**

# %% [markdown]
# ###**EdStatsData:-**
#
# **Country Name:** Names of the countries
#
# **Country Code:** Short codes for countries
#
# **Indicator Name:** This data is dependent on various indicators that resembles various factors that affect the overall Education growth and development of the country.
#
# **Indicator Code:** the codes given to different indicators such as Enrolment in early childhood education, both sexes (number) -UIS.E.0.T
#
# **Year Columns** (contains columns for each year from 1970 to 2100)
#
# ###**EdStatsCountry:-**
#
# This data contains variables such as Currency, Region, Income Group, Population census, household survey, Source of Income and Expenditure data, Latest Agricultural, Industrial and Trade data and so on.
#
# ###**EdStatsCountry-Series:-**
#
# **CountryCode:-** Codes of countries
#
# **SeriesCode:-** Codes of various indicators
#
# **DESCRIPTION:-** Data Sources from which these Indicators have been derived
#
# ###**EdStatsFootNote:-**
#
# **CountryCode** along with their respective description. tells the nature of Indicators, if its an estimate value or a percentage distribution
#
# ###**EdStatsSeries:-**
#
# Contains regional learning assessments data (e.g. **PISA TIMSS PIRLS**)

# %% [markdown]
# ##The following Indicators have been chosen for analysis:-
# **Education**
#
# Enrolment in early childhood education, both sexes (number) - **UIS.E.0.T**
#
# Enrolment in primary education, both sexes (number) - **SE.PRM.ENRL**
#
# Enrolment in secondary education, both sexes (number) - **SE.SEC.ENRL**
#
# Enrolment in tertiary education, both sexes (number) - **SE.TER.ENRL**
#
# Enrolment in post-secondary non-tertiary education, both sexes (number) - **UIS.E.4**
#
# **Expenditures**
#
# Government expenditure on education as % of GDP (%) - **SE.XPD.TOTL.GD.ZS**
#
# Expenditure on education as % of total government expenditure (%) - **SE.XPD.TOTL.GB.ZS**
#
# **Literacy**
#
# Adult literacy rate, population 15+ years, both sexes (%) - **SE.ADT.LITR.ZS**
#
# Adult illiterate population, 15+ years, both sexes (number) - **UIS.LP.AG15T99**
#
# **Population**
#
# School age population, pre-primary education, both sexes (number) - **SP.PRE.TOTL.IN**
#
# School age population, primary education, both sexes (number) - **SP.PRM.TOTL.IN**
#
# School age population, secondary education, both sexes (number) - **SP.SEC.TOTL.IN**
#
# School age population, tertiary education, both sexes (number) - **SP.TER.TOTL.IN**
#
# **Learning Outcomes**
#
# PISA: Mean performance on the Reading scale (number) - **LO.PISA.REA**
#
# PISA: Mean performance on the Mathematics scale (number) - **LO.PISA.MAT**
#
# ##The following Countries have been chosen for analysis:-
# **Canada, China, India, Japan, Pakistan, United Kingdom, United States**

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in ed_stats_country_series_df.columns.tolist():
  print("No. of unique values in ",i,"is",ed_stats_country_series_df[i].nunique())
# Out:
# No. of unique values in  CountryCode is 211
# No. of unique values in  SeriesCode is 21
# No. of unique values in  DESCRIPTION is 97
# No. of unique values in  Unnamed: 3 is 0

# %%
for i in ed_stats_country.columns.tolist():
  print("No. of unique values in ",i,"is",ed_stats_country[i].nunique())
# Out:
# No. of unique values in  Country Code is 241
# No. of unique values in  Short Name is 241
# No. of unique values in  Table Name is 241
# No. of unique values in  Long Name is 241
# No. of unique values in  2-alpha code is 238
# No. of unique values in  Currency Unit is 152
# No. of unique values in  Special Notes is 131
# No. of unique values in  Region is 7
# No. of unique values in  Income Group is 5
# No. of unique values in  WB-2 code is 240
# No. of unique values in  National accounts base year is 43
# No. of unique values in  National accounts reference year is 11
# No. of unique values in  SNA price valuation is 2
# No. of unique values in  Lending category is 3
# No. of unique values in  Other groups is 2
# No. of unique values in  System of National Accounts is 3
# No. of unique values in  Alternative conversion factor is 32
# No. of unique values in  PPP survey year is 3
# No. of unique values in  Balance of Payments Manual in use is 1
# ...

# %%
for i in ed_stats_data.columns.tolist():
  print("No. of unique values in ",i,"is",ed_stats_data[i].nunique())
# Out:
# No. of unique values in  Country Name is 242
# No. of unique values in  Country Code is 242
# No. of unique values in  Indicator Name is 3665
# No. of unique values in  Indicator Code is 3665
# No. of unique values in  1970 is 24595
# No. of unique values in  1971 is 30892
# No. of unique values in  1972 is 30982
# No. of unique values in  1973 is 30988
# No. of unique values in  1974 is 31139
# No. of unique values in  1975 is 37838
# No. of unique values in  1976 is 32679
# No. of unique values in  1977 is 32808
# No. of unique values in  1978 is 32887
# No. of unique values in  1979 is 32359
# No. of unique values in  1980 is 39456
# No. of unique values in  1981 is 34090
# No. of unique values in  1982 is 32969
# No. of unique values in  1983 is 33683
# No. of unique values in  1984 is 33903
# No. of unique values in  1985 is 41133
# No. of unique values in  1986 is 34774
# No. of unique values in  1987 is 34021
# No. of unique values in  1988 is 34013
# ...

# %%
for i in ed_stats_footnote.columns.tolist():
  print("No. of unique values in ",i,"is",ed_stats_footnote[i].nunique())
# Out:
# No. of unique values in  CountryCode is 239
# No. of unique values in  SeriesCode is 1558
# No. of unique values in  Year is 56
# No. of unique values in  DESCRIPTION is 9102
# No. of unique values in  Unnamed: 4 is 0

# %%
for i in ed_stats_Series.columns.tolist():
  print("No. of unique values in ",i,"is",ed_stats_Series[i].nunique())
# Out:
# No. of unique values in  Series Code is 3665
# No. of unique values in  Topic is 37
# No. of unique values in  Indicator Name is 3665
# No. of unique values in  Short definition is 1169
# No. of unique values in  Long definition is 2060
# No. of unique values in  Unit of measure is 0
# No. of unique values in  Periodicity is 1
# No. of unique values in  Base Period is 4
# No. of unique values in  Other notes is 14
# No. of unique values in  Aggregation method is 3
# No. of unique values in  Limitations and exceptions is 9
# No. of unique values in  Notes from original source is 0
# No. of unique values in  General comments is 8
# No. of unique values in  Source is 31
# No. of unique values in  Statistical concept and methodology is 2
# No. of unique values in  Development relevance is 1
# No. of unique values in  Related source links is 1
# No. of unique values in  Other web links is 0
# No. of unique values in  Related indicators is 0
# No. of unique values in  License Type is 0
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# The Data wrangling is the process of extracting and discovering patterns in large data sets. Data Cleaning is one of the most integral part of analysis, in order to get something meaningful out of a huge dataset we need to figure out how to extract a generalized, smaller and more skewed sub-dataFrame out of it.

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# List of selected indicators for analysis.
Indicators = [# Education
              "UIS.E.0.T", "SE.PRM.ENRL", "SE.SEC.ENRL", "SE.TER.ENRL", "UIS.E.4",
              # Expenditures
              "SE.XPD.TOTL.GD.ZS", "SE.XPD.TOTL.GB.ZS",
              # Literacy
              "SE.ADT.LITR.ZS", "UIS.LP.AG15T99",
              # Population
              "SP.PRE.TOTL.IN", "SP.PRM.TOTL.IN", "SP.SEC.TOTL.IN", "SP.TER.TOTL.IN",
              # Learning outcomes
              "LO.PISA.REA", "LO.PISA.MAT"]


# length of Indicators list.
len(Indicators)
# Out:
# 15

# %%
# List of countries that have been selected for analysis.
Countries = ["India", "United States", "United Kingdom", "Canada", "Japan", "China", "Pakistan"]
len(Countries)
# Out:
# 7

# %% [markdown]
# We want a columnwise sub dataset that would have the selected countries as columns with the set of meaningful years (those columns/Years that have at least one available value is considered) as rows.
# This type of data is suitable for plotting line charts and get meaningful insights accross the trends it produces.
# TO achieve this we will define a function which will extract data for all available countries, and then we can extract from this data the datset for the countries which we have selected.

# %%
def columnwise_data(indicator_Code):
  '''we are extracting data such as "countries, year wise data" for a particular indicator code, as this data is suitable for plotting graphs'''
  # we start with extracting rows of the particular indicator
  df = ed_stats_data[ed_stats_data["Indicator Code"] == indicator_Code]

  # then from the subset of the data we extract rows of the countries for which we are analysing
  df = df.loc[df["Country Name"].isin(Countries)]

  # we drop the columns containing all NaN's Values as these columns are not required
  df.dropna(how="all", axis = 1, inplace=True)

  # after getting the dataframe we reset its index as previous indexes are rendered useless after the filtration applied
  df.reset_index(inplace=True)

  # we extract the Indicator name of the indicator code we provided
  title = df["Indicator Name"][0]

  # the dataframe thus obtained contains indicator code, Indicator name, Country Code and old index numbers which we do not require, so we drop them
  df.drop(labels = ["index", "Country Code", "Indicator Name", "Indicator Code"], axis = 1, inplace = True)

  # To get a clear picture of dataframe containing countries and yearwise data we transpose it
  df = df.T

  # Now as we have transposed the data we need to reset index again
  df.reset_index(inplace=True)

  # the datafame thus obtained contains columns of year and countries,
  # but their labels are the previous index numbers
  # so to change columns name we will define new columns name & set them as our new columns
  new_columns = [ "Year", "Canada", "China", "India", "Japan", "Pakistan", "United Kingdom", "United States"]

  df.set_axis(new_columns, axis=1, inplace=True)

  # the 0th row is now unneccessary as it contains same values as columns name so we drop it
  df.drop(0, inplace=True)

  # the dataframe that we wanted is now generated, so we return df and title
  return df, title

# %%
# to check if our function works or not we will pass and indicator code through our function
df, title = columnwise_data("SE.PRM.ENRL")
df
# Out:
# <ipython-input-64-69d60e1eb801>:32: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(new_columns, axis=1, inplace=True)
#     Year     Canada        China        India       Japan    Pakistan  \
# 1   1970        NaN  100668000.0          NaN         NaN         NaN
# 2   1971  2846220.0  105280000.0   57045440.0   9630815.0   3992834.0
# 3   1972  2786106.0  112112000.0   58818644.0   9728516.0   4119577.0
# 4   1973  2695021.0  125492000.0   62400628.0   9825682.0   4460497.0
# 5   1974  2597576.0  135704000.0   63125100.0   9816536.0   4813134.0
# 6   1975  2534137.0  144814000.0   64855640.0  10088776.0   4988873.0
# 7   1976  2440016.0  150940992.0   65660024.0  10364846.0   5236203.0
# 8   1977  2361318.0  150055008.0   69060728.0  10609985.0   5527860.0
# 9   1978  2295925.0  146176000.0   67360992.0  10819651.0   5015479.0
# ...

# %%
# To get rowwise data we can just use the above function and change it accordingly
def rowwise_data(indicator_code):
  '''If we want to get the data rowwise we can just get data columnwise first and then make neccessary changes'''
  df, title = columnwise_data(indicator_code)

  # After getting the dataframe we extract years so that we can later use it to provude column names after transpose
  cols = list(df["Year"])

  #  first we transpose our dataframe
  df = df.T

  #  Then we reset index
  df.reset_index(inplace=True)

  # Then we provide the columns names to the new dataframe using the list of years that we extracted before
  df.set_axis((["Country Name"]+cols), axis=1, inplace=True)

  #  then we drop the 0th row as it is just the duplicated values of the column names
  df.drop(0, inplace=True)

  return df, title

# %%
# to check if our row wise function works or not we will pass and indicator code through our function
df, title = rowwise_data("SE.PRM.ENRL")
df
# Out:
# <ipython-input-64-69d60e1eb801>:32: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(new_columns, axis=1, inplace=True)
# <ipython-input-66-e360a5d82758>:16: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis((["Country Name"]+cols), axis=1, inplace=True)
#      Country Name         1970         1971         1972         1973  \
# 1          Canada          NaN    2846220.0    2786106.0    2695021.0
# 2           China  100668000.0  105280000.0  112112000.0  125492000.0
# 3           India          NaN   57045440.0   58818644.0   62400628.0
# 4           Japan          NaN    9630815.0    9728516.0    9825682.0
# 5        Pakistan          NaN    3992834.0    4119577.0    4460497.0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I extracted the dataframe as well as indicator name by performing rowwise_data() and columnwise_Data() functions on the EdStatsData dataset. For performing this I made a list of indicators which I found meaningful & relevant to my analysis and also a list of countries for which I wanted to do the analysis. then I made the above mentioned functions to retrieve the data columnwise and rowwise from the EdStatsData so that i can further work on it to derive meaningful correlations and insights  and figure out trends and patterns.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # Education
#
# **Early Childhood Education**
#
# Early childhood education (ECE), also known as nursery education, is a branch of education theory that relates to the teaching of children (formally and informally) from birth up to the age of eight. Traditionally, this is up to the equivalent of third grade.ECE is described as an important period in child development.
#
# The World Bank's 2019 World Development Report on The Changing Nature of Work  identifies early childhood development programs as one of the most effective ways governments can equip children with the skills they will need to succeed in future labor markets.

# %%
# Chart - 1 visualization code

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 16

# %%
# Calling columniwse_data() function to get dataframe for first indicator and also its tilte
first_indicator, title = columnwise_data(Indicators[0])

# Displaying title of the indicator
print(title)

# Displaying the dataframe obtained
first_indicator
# Out:
# Enrolment in early childhood education, both sexes (number)
#     Year    Canada       China      India      Japan Pakistan United Kingdom  \
# 1   1999       NaN  24030344.0        NaN        NaN      NaN            NaN
# 2   2000       NaN  23262588.0        NaN  3425697.0      NaN            NaN
# 3   2001       NaN  22441806.0  2617403.0  3463487.0      NaN            NaN
# 4   2002       NaN  20218371.0  4623168.0  3492456.0      NaN            NaN
# 5   2003       NaN  20360245.0  5507559.0  3555478.0      NaN            NaN
# 6   2004       NaN         NaN  5050006.0  3586547.0      NaN            NaN
# 7   2005       NaN         NaN  4761485.0  3615999.0      NaN            NaN
# 8   2006       NaN         NaN  5264053.0  3630184.0      NaN       989596.0
# 9   2007  486874.0  22638509.0  5366340.0  3614874.0      NaN      1004677.0
# 10  2008       NaN  23488300.0  6576483.0  3606830.0      NaN      1108148.0
# ...

# %%
# Cyrating the dataframe obtained as it contains too many NaN values
# Using ffill method to perform upward fill for NaN values,
# it replaces the NaN with the nearest value above it in the column
first_indicator.fillna(method="ffill", inplace= True)

# Using bfill method to perform downward fill for NaN values,
# it replaces the NaN with the nearest value below it in the column
first_indicator.fillna(method="bfill", inplace= True)

# Displaying the Matrix obtained
first_indicator
# Out:
#     Year    Canada       China      India      Japan  Pakistan  \
# 1   1999  486874.0  24030344.0  2617403.0  3425697.0       NaN
# 2   2000  486874.0  23262588.0  2617403.0  3425697.0       NaN
# 3   2001  486874.0  22441806.0  2617403.0  3463487.0       NaN
# 4   2002  486874.0  20218371.0  4623168.0  3492456.0       NaN
# 5   2003  486874.0  20360245.0  5507559.0  3555478.0       NaN
# 6   2004  486874.0  20360245.0  5050006.0  3586547.0       NaN
# 7   2005  486874.0  20360245.0  4761485.0  3615999.0       NaN
# 8   2006  486874.0  20360245.0  5264053.0  3630184.0       NaN
# 9   2007  486874.0  22638509.0  5366340.0  3614874.0       NaN
# 10  2008  486874.0  23488300.0  6576483.0  3606830.0       NaN
# 11  2009  486874.0  24749600.0  5839725.0  3579867.0       NaN
# 12  2010  486874.0  26578141.0  5570382.0  3513892.0       NaN
# 13  2011  486874.0  29766695.0  5936510.0  3455771.0       NaN
# 14  2012  486874.0  34244456.0  6073502.0  3476431.0       NaN
# ...

# %%
first_indicator.plot(x="Year", kind = 'line', title = title, xlabel = "Years", ylabel = "Enrollment in ECE",
                     figsize = (16,8), fontsize = 14, marker = 'o', linestyle = "--", grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As this data datframe contains 7 countries data, it will be easier to analyse it if we use line chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above Graph it is apparent that **China** is leading in ECE followed by **United States**. However, we see that **India** started out below **Japan** but gained a significant rise in 2002 and it kept on increasing coming closer to **USA**. **UK** and **Canada** remained constant throughout these years, they are below **India**, but this can be attributed to their low populations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The above insights will help in deciding the Policy Makers realise what has worked so far and what policies helped in bringing major positive changes in ECE of the country in the previous years. And looking at the trends, the future policies can be shaped in bringing out higher outcomes.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **Enrolment in primary eductaion, both sexes**

# %%
# Chart - 2 visualization code

# %%
# Calling rowwise_data() function to get dataframe for Second indicator and also its tilte
second_indicator, title2 = rowwise_data(Indicators[1])

# Displaying title of the indicator
print(title2)

# Displaying the dataframe obtained
second_indicator
# Out:
# Enrolment in primary education, both sexes (number)
#      Country Name         1970         1971         1972         1973  \
# 1          Canada          NaN    2846220.0    2786106.0    2695021.0
# 2           China  100668000.0  105280000.0  112112000.0  125492000.0
# 3           India          NaN   57045440.0   58818644.0   62400628.0
# 4           Japan          NaN    9630815.0    9728516.0    9825682.0
# 5        Pakistan          NaN    3992834.0    4119577.0    4460497.0
# 6  United Kingdom          NaN    5806349.0    5880238.0    5888063.0
# 7   United States          NaN   22037000.0   21676000.0   21873000.0
#
#           1974         1975         1976         1977         1978  ...  \
# 1    2597576.0    2534137.0    2440016.0    2361318.0    2295925.0  ...
# 2  135704000.0  144814000.0  150940992.0  150055008.0  146176000.0  ...
# 3   63125100.0   64855640.0   65660024.0   69060728.0   67360992.0  ...
# ...

# %%
# Curating the dataframe obtained as it contains too many NaN values
# Now, we need to replace 'NaN' values from the matrix. Here we are using a column mean to fill null values
# since average of values provide a better estimation for the type of data we have in a row wise matrix.
# Also we are selecting limited number of columns for analysis so the repetative mean values won't affect
# much of our visualization.
second_indicator.fillna(second_indicator.mean(), inplace=True)

# Displaying the Matrix obtained
second_indicator
# Out:
# <ipython-input-50-b86650b0529d>:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   second_indicator.fillna(second_indicator.mean(), inplace=True)
#      Country Name         1970         1971         1972         1973  \
# 1          Canada  100668000.0    2846220.0    2786106.0    2695021.0
# 2           China  100668000.0  105280000.0  112112000.0  125492000.0
# 3           India  100668000.0   57045440.0   58818644.0   62400628.0
# 4           Japan  100668000.0    9630815.0    9728516.0    9825682.0
# 5        Pakistan  100668000.0    3992834.0    4119577.0    4460497.0
# 6  United Kingdom  100668000.0    5806349.0    5880238.0    5888063.0
# 7   United States  100668000.0   22037000.0   21676000.0   21873000.0
#
#           1974         1975         1976         1977         1978  ...  \
# ...

# %%
second_indicator.plot(x="Country Name", y=["1980","1990","2000","2010"],  kind = 'bar', title = title, xlabel = "Countries",
                      ylabel = "Enrollment in Primary Education", figsize = (16,8), fontsize = 14, rot=0, grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose Bar plot to show how the countries have progressed in every decade. India has shown Linear positive growth in the number of enrolments in primary education.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows that there is continuous spread of awareness in Indian parents about the importance of education and so the enrolment in primary education is showing positive growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Awareness programmes, midday meals policy and other govt initiated programmes are working well to ensure enrolments in primary education.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %%
def get_dataframe(year):
  temp, title_ = rowwise_data(Indicators[1])
  countries = temp["Country Name"]
  cols =["Primary","Secondary","Tertiary","Post-Secondary-Non-Tertiary"]
  temporary_df = pd.DataFrame()
  empty_list = []
  for i in range(1,5):
    temp1, titles = rowwise_data(Indicators[i])
    empty_list.append(list(temp1[str(year)]))

  temporary_df = pd.DataFrame(empty_list, columns = countries, index = cols)
  temporary_df.fillna(temporary_df.mean(), inplace=True)

  return temporary_df.T

# %%
year = 2011
temporary_df_1 = get_dataframe(year)
temporary_df_1.reset_index(inplace=True)
temporary_df_1.plot(x="Country Name", kind = 'bar', title = "Enrolment in Primary, Secondary, Tertiary and Post-secondary Non-Tertiary Education ",
                    xlabel = "Countries", ylabel = f"Enrollment in different Classes in {year}",rot=0,
                    figsize = (16,8), fontsize = 14, grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show how many Students are enrolling in **Primary, Secondary, Tertiary And Non-Tertiary education sector** of a country in a particular year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This graph shows That the enrolment in primary section is much higher than any other sector, which in turn says that many students are dropping out of schools in secondary and then in tertiary courses. The Govt need to bring initiatives such as scholarships, paid internships in govt offices, voactional courses, interactive classes in higher classes to attract more students.
#
# The no of students enrolling in Non-tertiary courses in **America** is significantly more than any other country which shows the diverse career choices provided to students there.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# It creates a positive impact on our business as it steers us in right direction.

# %% [markdown]
# ##**Expenditures by Government**

# %% [markdown]
# Public expenditure is referred as the expenses incurred by the Government for the maintenance of the government responsibility and to stimulate the welfare of the society.
#
# Education is not a pure public good, because in certain situations education might violate the principle characteristics of the public good such as non-rival and non-excludability.
#
# But education in general or elementary education in particular is considered as social good or collective good, which produces various positive externalities and social advantages to the society.
#
# Several economists have supported public expenditure on education for providing better educational opportunities in the society based on the argument that expenditure on education impacts economic development positively.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# **Government ex[enditure on education as % of GDP.**

# %%
# Chart - 4 visualization code

# %%
# Extracting the matrix required
sixth_indicator, title6 = columnwise_data(Indicators[5])

# Displaying the titles of the indicator
print(title6)

# Printing the matrix
sixth_indicator
# Out:
# Government expenditure on education as % of GDP (%)
#     Year   Canada    China    India    Japan Pakistan United Kingdom  \
# 1   1971  7.71019  1.38699      NaN  3.71648  1.65429        5.03205
# 2   1972  7.63406  1.60627      NaN  4.07991  1.57826        5.15938
# 3   1973  7.03377  1.64855      NaN  4.11199  1.85125        5.44861
# 4   1974  6.70673  1.75972      NaN  4.12426  1.89806          5.391
# 5   1975  6.43802  1.70822      NaN  4.73971  2.00856        6.26878
# 6   1976  6.71431  1.81572      NaN  4.93977  2.22161        6.44037
# 7   1977  6.72308  1.74954      NaN  4.92031  2.12319         6.0845
# 8   1978  7.09923  1.95815      NaN  4.98988  2.20048            NaN
# 9   1979  6.72539  2.14829      NaN  5.13707  2.20224            NaN
# 10  1980  6.47863  1.91089      NaN   5.1624  2.13002        5.07729
# 11  1981  6.43443  1.94717      NaN  5.15984  1.96556        5.29054
# 12  1982  6.52129  2.03575      NaN  5.11901  2.01509        5.19033
# ...

# %%
# Cleaning data to replace null values using backward and forward filling methods.
# First using "ffill" on data.
sixth_indicator.fillna(method = "ffill", inplace = True)

# now using "bfill" on data.
sixth_indicator.fillna(method = "bfill", inplace = True)

# Displaying cleaned matrix.
sixth_indicator
# Out:
#     Year   Canada    China    India    Japan  Pakistan  United Kingdom  \
# 1   1971  7.71019  1.38699  3.30847  3.71648   1.65429         5.03205
# 2   1972  7.63406  1.60627  3.30847  4.07991   1.57826         5.15938
# 3   1973  7.03377  1.64855  3.30847  4.11199   1.85125         5.44861
# 4   1974  6.70673  1.75972  3.30847  4.12426   1.89806         5.39100
# 5   1975  6.43802  1.70822  3.30847  4.73971   2.00856         6.26878
# 6   1976  6.71431  1.81572  3.30847  4.93977   2.22161         6.44037
# 7   1977  6.72308  1.74954  3.30847  4.92031   2.12319         6.08450
# 8   1978  7.09923  1.95815  3.30847  4.98988   2.20048         6.08450
# 9   1979  6.72539  2.14829  3.30847  5.13707   2.20224         6.08450
# 10  1980  6.47863  1.91089  3.30847  5.16240   2.13002         5.07729
# 11  1981  6.43443  1.94717  3.30847  5.15984   1.96556         5.29054
# 12  1982  6.52129  2.03575  3.30847  5.11901   2.01509         5.19033
# ...

# %%
sixth_indicator[20:].plot(x = "Year", y = ["India", "United States", "Pakistan", "China"],
                     kind = 'line', title = title6, xlabel = "Years",
                     ylabel = "% of GDP expenditure",subplots = True,
                     layout = (2,2),ylim = (1, 7),
                     linewidth = 0.5, linestyle ="--", figsize = (16,8),
                     fontsize = 14, marker = "o", grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this Line chart with subplots for comparing the percentage of GDP each country is expending on education as it gives clear results as to which country expends the most percentage of its GDP on education.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above split line chart it is evident that **USA** spends the highest amount in terms of its GDP Percentage closely follwed by **India**.
#
# We can see from the Graph that Pakistan expenditure on education is more than China if we talk in terms of Percentage of GDP, but China's GDP is so much more than Pakistan, the amount of China is still more than Pakistan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# As we are clearly able to see each country's expenditure on education in terms of GDP, we can draw better correlations between expenditure and outcomes.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# **Expenditure on Education as % of total government expenditure.**

# %%
# Chart - 5 visualization code

# %%
# Extracting the required Matrix
seventh_indicator, title7 = rowwise_data(Indicators[6])

# printing the title
print(title7)

# printing the matrix
seventh_indicator
# Out:
# Expenditure on education as % of total government expenditure (%)
#      Country Name      1981      1982      1983      1984      1985      1986  \
# 1          Canada   15.5789  15.53181  14.77497   14.0908  13.23688   12.6832
# 2           China       NaN       NaN   9.56325   9.76224  10.68738  10.43901
# 3           India       NaN       NaN       NaN       NaN       NaN       NaN
# 4           Japan  16.08354  15.64062  14.91423       NaN       NaN       NaN
# 5        Pakistan       NaN       NaN       NaN       NaN       NaN       NaN
# 6  United Kingdom  12.64421  11.60222  11.40756  11.20601  10.45942  10.21579
# 7   United States       NaN       NaN       NaN       NaN       NaN       NaN
#
#        1987       1988      1989  ...      2006      2007      2008      2009  \
# 1  13.45583   13.53854  13.56977  ...       NaN  12.32856  12.00996  12.48364
# 2   9.46158   10.74394       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
# Filling Null values with column wise mean.
seventh_indicator.fillna(seventh_indicator.mean(), inplace = True)

# Displaying cleaned matrix.
seventh_indicator
# Out:
# <ipython-input-20-62f40223004d>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   seventh_indicator.fillna(seventh_indicator.mean(), inplace = True)
#      Country Name       1981       1982       1983      1984       1985  \
# 1          Canada  15.578900  15.531810  14.774970  14.09080  13.236880
# 2           China  14.768883  14.258217   9.563250   9.76224  10.687380
# 3           India  14.768883  14.258217  12.665003  11.68635  11.461227
# 4           Japan  16.083540  15.640620  14.914230  11.68635  11.461227
# 5        Pakistan  14.768883  14.258217  12.665003  11.68635  11.461227
# 6  United Kingdom  12.644210  11.602220  11.407560  11.20601  10.459420
# 7   United States  14.768883  14.258217  12.665003  11.68635  11.461227
#
#         1986       1987       1988       1989  ...      2006       2007  \
# ...

# %%
seventh_indicator.plot(x = "Country Name", y = ["2000", "2005", "2014"], kind='barh', title = title7,
                       xlabel = "Countries", ylabel = "% of Govt Expenditure",xlim = (0,25),
                       figsize = (16,8), fontsize = 14, layout = (3,1), subplots= True, grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart gives an year-wise insight into expenditure on education of different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that **India** spent the most in education in **year 2000** and then the expenditure on education as % of govt expenditure reduced over the years.
#
# We also observe that **Pakistan** has increased its expenditure on education from 2000 to 2014.
#
# **Japan's** expenditure on education has remained almost same over the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# **India** is now expending almost as much as **China** on Education sector which is a positive development for India. So the Govt sources are being put in the right direction.

# %% [markdown]
# ##**Literacy**

# %% [markdown]
# Literacy is the process of expanding one's knowledge of reading and writing in order to develop their thinking and learning for the purpose of understanding themselves and the world. Higher literacy rates are associated with less crime rates, greater economic growth, and higher employment rates. For a person, literacy is a foundational skill required to acquire advanced skills.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# **Adult literacy rate, population 15+ years, both sexes**

# %%
# Chart - 6 visualization code

# %%
# Extracting the required matrix
eighth_indicator, title8 = columnwise_data(Indicators[7])

# printing title
print(title8)

# printing the matrix
eighth_indicator
# Out:
# Adult literacy rate, population 15+ years, both sexes (%)
#     Year Canada      China      India Japan   Pakistan United Kingdom  \
# 1   1981    NaN        NaN  40.763592   NaN  25.725189            NaN
# 2   1982    NaN  65.505089        NaN   NaN        NaN            NaN
# 3   1990    NaN  77.785057        NaN   NaN        NaN            NaN
# 4   1991    NaN        NaN  48.222069   NaN        NaN            NaN
# 5   1998    NaN        NaN        NaN   NaN   42.69931            NaN
# 6   2000    NaN   90.92021        NaN   NaN        NaN            NaN
# 7   2001    NaN        NaN   61.01456   NaN        NaN            NaN
# 8   2005    NaN        NaN        NaN   NaN   49.87364            NaN
# 9   2006    NaN        NaN   62.75447   NaN   54.15121            NaN
# 10  2008    NaN        NaN        NaN   NaN   55.52637            NaN
# 11  2009    NaN        NaN        NaN   NaN   54.89264            NaN
# 12  2010    NaN   95.12448        NaN   NaN   55.37519            NaN
# ...

# %%
# Dropping the columns which contain all NaN values
eighth_indicator.dropna(how = "all", axis=1, inplace=True)

# curating the obtained matrix with fillna
eighth_indicator.fillna(method ="ffill", inplace=True)
eighth_indicator.fillna(method ="bfill", inplace=True)

# Display the curated MAtrix
eighth_indicator
# Out:
#     Year      China      India   Pakistan
# 1   1981  65.505089  40.763592  25.725189
# 2   1982  65.505089  40.763592  25.725189
# 3   1990  77.785057  40.763592  25.725189
# 4   1991  77.785057  48.222069  25.725189
# 5   1998  77.785057  48.222069  42.699310
# 6   2000  90.920210  48.222069  42.699310
# 7   2001  90.920210  61.014560  42.699310
# 8   2005  90.920210  61.014560  49.873640
# 9   2006  90.920210  62.754470  54.151210
# 10  2008  90.920210  62.754470  55.526370
# 11  2009  90.920210  62.754470  54.892640
# 12  2010  95.124480  62.754470  55.375190
# 13  2011  95.124480  69.302560  54.738020
# 14  2012  95.124480  69.302560  56.764340
# 15  2013  95.124480  69.302560  55.594990
# 16  2014  95.124480  69.302560  56.977150

# %%
# plotting Box Graph
eighth_indicator.plot(x = "Year", y = ["India","China","Pakistan"], kind = 'box', title = title8,
                xlabel = "Countries", ylabel = "% of Adult Literacy",
                figsize=(12,8), ylim = (25,100), fontsize = 14,
                grid = True)

# %%
eighth_indicator.plot(x="Year", kind = 'line', title = title, xlabel = "Years", ylabel = "% of Adult Literacy",
                      figsize = (16,8), fontsize = 14, marker = 'o', linestyle = "--", grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The First Chart shows the percentage of adult literate population in box chart which helps in understanding the median values.
#
# The Second chart shows growth in numbers of adult literate population yearwise which helps in understanding how these numbers are increasing or decreasing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The First Chart shows the percentage of adult literate population in box chart, from which it is shown that **India's** adult literate population varies from as low as 40% to as high as 70% with its median around 65%, which says that **India's** adult literate population have always been more than 50% and closer to 70% which is a good percentage.
#
# In the 2nd line plot graph it is evident that **China's** adult literate population have always been more than our country and it has been increasing constantly.
#
# On the other hand **Pakistan's** adult literate population saw tremendous increase from 1995 to 1998 and it is also showing positive growth, reaching almost equal to **India's** literate population. However, if we see its median value it is around 55% which is still a good number.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The first chart informs us that the distribution of values for this indicator, is concentrated in the upper region of the graph, which shows that the literacy rate has mostly been above the 50% mark.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# **Adult illiterate population, 15+ years, both sexes**

# %%
# Chart - 7 visualization code

# %%
# Extracting the required matrix
ninth_indicator, title9 = columnwise_data(Indicators[8])

# printing title
print(title9)

# printing the matrix
ninth_indicator
# Out:
# Adult illiterate population, 15+ years, both sexes (number)
#     Year Canada        China        India Japan    Pakistan United Kingdom  \
# 1   1981    NaN          NaN  255191968.0   NaN  33947896.0            NaN
# 2   1982    NaN  227240528.0          NaN   NaN         NaN            NaN
# 3   1990    NaN  182658288.0          NaN   NaN         NaN            NaN
# 4   1991    NaN          NaN  286798080.0   NaN         NaN            NaN
# 5   1998    NaN          NaN          NaN   NaN  43962252.0            NaN
# 6   2000    NaN   86449754.0          NaN   NaN         NaN            NaN
# 7   2001    NaN          NaN  274237172.0   NaN         NaN            NaN
# 8   2005    NaN          NaN          NaN   NaN  47295739.0            NaN
# 9   2006    NaN          NaN  287691648.0   NaN  44890961.0            NaN
# 10  2008    NaN          NaN          NaN   NaN  46508867.0            NaN
# 11  2009    NaN          NaN          NaN   NaN  47763388.0            NaN
# ...

# %%
# Dropping the columns which contain all NaN values
ninth_indicator.dropna(how = "all", axis=1, inplace=True)

# curating the obtained matrix with fillna
ninth_indicator.fillna(method ="ffill", inplace=True)
ninth_indicator.fillna(method ="bfill", inplace=True)

# Display the curated MAtrix
ninth_indicator
# Out:
#     Year        China        India    Pakistan
# 1   1981  227240528.0  255191968.0  33947896.0
# 2   1982  227240528.0  255191968.0  33947896.0
# 3   1990  182658288.0  255191968.0  33947896.0
# 4   1991  182658288.0  286798080.0  33947896.0
# 5   1998  182658288.0  286798080.0  43962252.0
# 6   2000   86449754.0  286798080.0  43962252.0
# 7   2001   86449754.0  274237172.0  43962252.0
# 8   2005   86449754.0  274237172.0  47295739.0
# 9   2006   86449754.0  287691648.0  44890961.0
# 10  2008   86449754.0  287691648.0  46508867.0
# 11  2009   86449754.0  287691648.0  47763388.0
# 12  2010   53766856.0  287691648.0  48536149.0
# 13  2011   53766856.0  265567691.0  50300662.0
# 14  2012   53766856.0  265567691.0  49313655.0
# 15  2013   53766856.0  265567691.0  51955838.0
# 16  2014   53766856.0  265567691.0  51635852.0

# %%
ninth_indicator.plot(x = "Year", y = ["India","China","Pakistan"], kind = 'box', title = title9,
                xlabel = "Countries", ylabel = "% of Adult Illiteracy",
                figsize=(12,8),  fontsize = 14,
                grid = True)

# %%
ninth_indicator.plot(x="Year", kind = 'line', title = title, xlabel = "Years", ylabel = "% of Adult Illiteracy",
                      figsize = (16,8), fontsize = 14, marker = 'o', linestyle = "--", grid = True)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Box chart shows the extrems values and the median values which are useful for our evaluation.
#
# The line chart shows the trend which is useful in drawing conclusions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Median Illiterate adults in India is the highest of the three countries with Pakistan having the least number of illiterate adults. for **India** the median value is around 275 million while **China's** median value is around 80 million and **Pakistan's** median value is less than 50 million.
#
# the Second graph shows how **Indian** illeterate adult population increases but then decreases, while **China's** population showed a significant downward slope from 1981 to 2014. And if we see **Pakistan's** plot line we come to the conclusion that Pakistans illiterate adult population has increased over the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes the gained insights from the above two indicators tell that our literate adult population is increasing percentage-wise while our illeterate adult population is also increasing number-wise. This tells that although Government schemes are working to provide people with better education, India's population growth is making these efforts fruitless as number of illetrate people is also increasing.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# **Population**

# %% [markdown]
# Population of a country refers to the number of individual living in that country. These individuals are bonefied members of the country and contribute to various aspects of country's Statistics.
#
# Population majorly affects the Education and literacy. Rapid growth of population increases the rate of illiteracy and poverty. It also increases the disparity between rich and poor countries in their socio- economic as well as general life. causes imbalance in its use.

# %% [markdown]
# **As Mentioned before, we have selected 4 Indicators for this category:-**
#
# *   School age population, pre-primary education, both sexes (number)
# *   School age population, primary education, both sexes (number)
# *   School age population, secondary education, both sexes (number)
# *   School age population, tertiary education, both sexes (number)

# %%
# Chart - 8 visualization code

# %%
# Creating a list that contains all the Indicators that we require
Population_indicators = Indicators[9:13]

# forming two separate lists, 1 of Dataframes of these Indicators. 2nd of the titles of these inidcators
dataframes = []
titles_of_dataframes = []
for i in Population_indicators:
  # we get two values after applying columnwise_dat afunction so i have porvided two variables to store that values
    temporary_dataframe, temporary_title = columnwise_data(i)
    dataframes.append(temporary_dataframe), titles_of_dataframes.append(temporary_title)

print(len(dataframes))
print(len(titles_of_dataframes))
# Out:
# 4
# 4

# %%
# Cleaning the dataframes obtained by replacing NaN values with ffill or bfill
# We can run a for loop which will clean all the dataframes
for i in range(len(dataframes)):
  dataframes[i].fillna(method = "ffill", inplace=True)
  dataframes[i].fillna(method = "bfill", inplace = True)

dataframes[-1].describe()
# Out:
#              Canada         China         India         Japan      Pakistan  \
# count  4.600000e+01  4.600000e+01  4.600000e+01  4.600000e+01  4.600000e+01
# mean   2.198199e+06  1.068591e+08  8.607903e+07  8.227590e+06  1.126735e+07
# std    1.695414e+05  1.569331e+07  2.214329e+07  1.187820e+06  4.544551e+06
# min    1.897230e+06  8.282734e+07  4.740462e+07  6.095805e+06  4.866602e+06
# 25%    2.036877e+06  9.219947e+07  6.758175e+07  7.565330e+06  7.501738e+06
# 50%    2.198255e+06  1.060733e+08  8.456796e+07  8.171130e+06  1.048990e+07
# 75%    2.341444e+06  1.216909e+08  1.073861e+08  9.101018e+06  1.510576e+07
# max    2.481127e+06  1.304159e+08  1.194700e+08  1.058414e+07  1.885263e+07
#
#        United Kingdom  United States
# count    4.600000e+01   4.600000e+01
# mean     4.079376e+06   2.029251e+07
# std      3.778393e+05   1.430728e+06
# min      3.458626e+06   1.750729e+07
# 25%      3.806128e+06   1.909092e+07
# 50%      4.092635e+06   2.044427e+07
# ...

# %% [markdown]
# As we can see from the above mentioned description of the dataframe that the population of **Canada, Japan** and **United Kingdom** is very low compared to **China** and **India**. so we will drop them to analyse the countries more in line with **India's** population. so countries selected for analysis are:
#
#
# *   **India**
# *   **China**
# *   **United States**
# *   **Pakistan**

# %%
# defining a subplot object such that we can plot all 4 indicators on the same figure.
figure, axes = plt.subplots(nrows = 2, ncols = 2)

# a variable to call indexes of dataframes for various indicators.
k = 0

# Defining Nested for loops to plot (2,2) matric subplots.
for i in range(2):
  for j in range(2):

    # Plot function to plot various indicators.
    dataframes[k].plot(x = "Year",
                # passing list of countries selected to Y-axis.
                y = ["India", "China", "United States", "Pakistan"],
                kind = 'line',
                # we can pass the indicator name as title. Also rejecting the string "(number)" from the end.
                ylabel = (titles_of_dataframes[k])[:-8],
                xlabel = "Years", figsize = (20,10),
                grid = True,
                marker = ".",
                linewidth = 1,
                # 'ax' takes subplot indexes as input to plot graphs accordingly.
                ax = axes[i,j])

    # Incrementing 'k'.
    k = k + 1

plt.rcParams['axes.labelsize'] = 9
plt.rcParams['axes.titlesize'] = 9
# Below is the Graph obtained by all 4 indicators as subplots.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The subplots help in analysing all 4 dataframes at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs we can draw conclusion that **India** is showing consistent progress in the number of population entering different education classes. On the other hand **China** is showing very irregularities in its population entering pre-primary, primary, secondary and tertiary education.
#
# For the countries **Pakistan** and **United States**, we see an overall stable trend with minor fluctuations. This shows a potential focus towards stability and consistency in the population.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The sudden surge in the number of population in pre-primary section shows some monumental changes were brought in by govt to motivate people to send kids to school. This growth is a direct outcome of **The Midday Meal Scheme** which was implemented by India's Govt in late 90s. These results show that proper policies bring about major changes if they are formulated keeping in mind the needs of the people and implemented accordingly.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# **Learning Outcomes**

# %% [markdown]
# The Learning Outcomes category highlights levels of student learning in reading and mathematics in over 100 countries based on data from international learning assessments like PISA.
#
# **1. PISA: Mean performance on the reading scale**

# %% [markdown]
# We will take all the countries in this category.

# %%
# Chart - 9 visualization code

# %%
# EXtracting a Datframe which contains the data of the indiators selected, and because we want all the countries we are not using columnwise_Data() function.
dataframe_of_last2_indicators = ed_stats_data.loc[ed_stats_data['Indicator Code'] == Indicators[-2]]

# Resetting Index
dataframe_of_last2_indicators.reset_index(inplace=True)

# Getting the INdicator title
title14 = dataframe_of_last2_indicators["Indicator Name"][0]

# Creating a datframe of years for which mean value is required
col = dataframe_of_last2_indicators.loc[: , "1970":"2100"]

# Providing these values in a column
dataframe_of_last2_indicators['PISA_Reading_Mean'] = col.mean(axis=1)

# Removing rows that have null value in the PISA_Reading_Mean
dataframe_of_last2_indicators = dataframe_of_last2_indicators.dropna(subset = ['PISA_Reading_Mean'])

# Taking out only COuntry name and PISA_Reading_mean values because that is all we require
PISA_Reading_pie = dataframe_of_last2_indicators[["Country Name", "PISA_Reading_Mean"]]

# There are 77 rows, values more than 20 will make it unreadable. so we are taking last 20 values for displaying on bar chart
PISA_Reading_pie.sort_values(by="PISA_Reading_Mean").plot(x = "Country Name", y = "PISA_Reading_Mean", kind="bar", figsize = (18,8),
                            fontsize = 14, title = title14, xlabel = "Countries",
                            ylabel = "Mean Performance on reading scale")
# Out:
# <ipython-input-162-304ee2305f25>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_of_last2_indicators['PISA_Reading_Mean'] = col.mean(axis=1)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar Graph is easier to read when too many values are to be compared.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above bar plot we can derive the conclusion that for available "PISA_Reading_Mean" values, **Kyrgyz Republic** is at the lowest while **China** is at the highest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **India** is not present among the countreis of PISA reading ability tests. So no particular insights can be drawn for India.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# Now we will take the above bar graph and represnt it in chart form of a continent.

# %%
# Chart - 10 visualization code

# %%
# Creating a List of countries in Europe by copying list from internet and splitting it.
countries_in_eu = "Austria, Belgium, Bulgaria, Croatia, Republic of Cyprus, Czech Republic, Denmark, Estonia, Finland, France, Germany, Greece, Hungary, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Netherlands, Poland, Portugal, Romania, Slovakia, Slovenia, Spain, Sweden"
countries_in_eu_list = list(countries_in_eu.split(", "))

# 26 countries in europe using which we will create our dcitionary
Continent_name ='Europe'
Con=[]
Con.extend([Continent_name for i in range(len(countries_in_eu_list))])

# Creating a dictionary from the bove two list
Continent_dictionary = dict(zip(countries_in_eu_list,Con))
Another_dictionary = {'Denmark':'Europe','Slovenia':'Europe','Germany':'Europe','Iceland':'Europe','Vietnam':'Asia',
                      'Poland':'Europe','Macao SAR, China':'Asia','Switzerland':'Europe','Norway':'Europe','United Kingdom':'Europe',
                      'Sweden':'Europe','Belgium':'Europe','Liechtenstein'	:'Europe','Netherlands':'Europe','Estonia':'Europe','Japan':'Asia',
                      'Australia':'Oceania','Ireland':'Europe','New Zealand':'Oceania','Canada':'North America','Hong Kong SAR, China':'Asia',
                      'Singapore':'Asia', 'Korea, Rep.':'Asia','Finland':'Europe','China':'Asia'}
Continent_dictionary.update(Another_dictionary)


# Creating a column which contains the continent of each country
PISA_Reading_pie['Continent'] = PISA_Reading_pie['Country Name'].map(Continent_dictionary)

# Continents we got for the countries are
PISA_Reading_pie['Continent'].notnull().sum()

# Dropping rows with NaN value in column Continent
PISA_Reading_pie = PISA_Reading_pie.dropna(subset = ['Continent'])

# Grouping by continents and plotting pie charts
PISA_Reading_pie.groupby('Continent').sum().plot(kind ="pie", subplots =True, ylabel = "Pie Distribution", title = title14, explode =(.1,.1,.1,0),
                                                 figsize =(16,8), textprops={'fontsize': 14},legend=True, autopct = '%1.1f %%', shadow = True)
# Out:
# <ipython-input-169-398df8f89822>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PISA_Reading_pie['Continent'] = PISA_Reading_pie['Country Name'].map(Continent_dictionary)
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0aba6e8b80>],
#       dtype=object)

# %%
PISA_Reading_pie.groupby('Continent').sum()
# Out:
#                PISA_Reading_Mean
# Continent
# Asia                 3649.695474
# Europe              14642.148661
# North America         527.210663
# Oceania              1034.987574

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We wanted the parts of a whole, which are better represented by a pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above PIe chart it is shown that Eruope has the maximum percentage in PISA reading scale, which can be attributed to more students taking the exam and getting good grades, which is direct result of their government policies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help us in understanding which continent is performing better in terms of learning outcomes when it comes to students being able to read.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# **2. PISA: Mean performance on the mathematics scale**

# %%
# Chart - 11 visualization code

# %%
# EXtracting a Datframe which contains the data of the indiators selected, and because we want all the countries we are not using columnwise_Data() function.
dataframe_of_last_indicators = ed_stats_data.loc[ed_stats_data['Indicator Code'] == Indicators[-1]]

# Resetting Index
dataframe_of_last_indicators.reset_index(inplace=True)

# Getting the INdicator title
title15 = dataframe_of_last_indicators["Indicator Name"][0]

# Creating a datframe of years for which mean value is required
col = dataframe_of_last_indicators.loc[: , "1970":"2100"]

# Providing these values in a column
dataframe_of_last_indicators['PISA_Mathematic_Mean'] = col.mean(axis=1)

# Removing rows that have null value in the PISA_Mathematic_Mean
dataframe_of_last_indicators = dataframe_of_last_indicators.dropna(subset = ['PISA_Mathematic_Mean'])

# Taking out only COuntry name and PISA_Mathematic_Mean values because that is all we require
PISA_Mathematic_pie = dataframe_of_last_indicators[["Country Name", "PISA_Mathematic_Mean"]]

# There are 77 rows, values more than 20 will make it unreadable. so we are taking last 20 values for displaying on bar chart
PISA_Mathematic_pie.sort_values(by="PISA_Mathematic_Mean").plot(x = "Country Name", y = "PISA_Mathematic_Mean", kind="bar", figsize = (18,8),
                            fontsize = 14, title = title15, xlabel = "Countries",
                            ylabel = "Mean Performance on mathematic scale")
# Out:
# <ipython-input-165-e67a9e405866>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_of_last_indicators['PISA_Mathematic_Mean'] = col.mean(axis=1)

# %%
# Creating a List of countries in Europe by copying list from internet and splitting it.
countries_in_eu = "Austria, Belgium, Bulgaria, Croatia, Republic of Cyprus, Czech Republic, Denmark, Estonia, Finland, France, Germany, Greece, Hungary, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Netherlands, Poland, Portugal, Romania, Slovakia, Slovenia, Spain, Sweden"
countries_in_eu_list = list(countries_in_eu.split(", "))

# 26 countries in europe using which we will create our dcitionary
Continent_name ='Europe'
Con=[]
Con.extend([Continent_name for i in range(len(countries_in_eu_list))])

# Creating a dictionary from the bove two list
Continent_dictionary = dict(zip(countries_in_eu_list,Con))
Another_dictionary = {'Denmark':'Europe','Slovenia':'Europe','Germany':'Europe','Iceland':'Europe','Vietnam':'Asia',
                      'Poland':'Europe','Macao SAR, China':'Asia','Switzerland':'Europe','Norway':'Europe','United Kingdom':'Europe',
                      'Sweden':'Europe','Belgium':'Europe','Liechtenstein'	:'Europe','Netherlands':'Europe','Estonia':'Europe','Japan':'Asia',
                      'Australia':'Oceania','Ireland':'Europe','New Zealand':'Oceania','Canada':'North America','Hong Kong SAR, China':'Asia',
                      'Singapore':'Asia', 'Korea, Rep.':'Asia','Finland':'Europe','China':'Asia'}
Continent_dictionary.update(Another_dictionary)


# Creating a column which contains the continent of each country
PISA_Mathematic_pie['Continent'] = PISA_Mathematic_pie['Country Name'].map(Continent_dictionary)

# Continents we got for the countries are
PISA_Mathematic_pie['Continent'].notnull().sum()

# Dropping rows with NaN value in column Continent
PISA_Mathematic_pie = PISA_Mathematic_pie.dropna(subset = ['Continent'])

# Grouping by continents and plotting pie charts
PISA_Mathematic_pie.groupby('Continent').sum().plot(kind ="pie", subplots =True, ylabel = "Pie Distribution", title = title15, explode =(.1,.1,.1,0),
                                                 figsize =(16,8), textprops={'fontsize': 14},legend=True, autopct = '%1.1f %%', shadow = True)
# Out:
# <ipython-input-166-a719c46a5623>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PISA_Mathematic_pie['Continent'] = PISA_Mathematic_pie['Country Name'].map(Continent_dictionary)
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0aba7a5b20>],
#       dtype=object)

# %%
PISA_Mathematic_pie.groupby('Continent').sum()
# Out:
#                PISA_Mathematic_Mean
# Continent
# Asia                    3815.137706
# Europe                 14781.182951
# North America            525.502811
# Oceania                 1031.051782

# %% [markdown]
# #### Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %%
# Calling columniwse_data() function to get dataframe for first indicator and also its tilte
first_indicator, title1 = columnwise_data(Indicators[0])

# Displaying title of the indicator
print(title)

# Displaying the dataframe obtained
first_indicator_Country = first_indicator[['Year','United States']]
first_indicator_Country.rename(columns = {'United States':"UIS.E.0.T"}, inplace=True)
first_indicator_Country
# Out:
# PISA: Mean performance on the mathematics scale
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Year      UIS.E.0.T
# 1   1999      7183122.0
# 2   2000      7110066.0
# 3   2001      7538720.0
# 4   2002      7667685.0
# 5   2003            NaN
# 6   2004      7435568.0
# 7   2005      7361682.0
# 8   2006      7342289.0
# 9   2007      7512518.0
# 10  2008      7191333.0
# 11  2009      7194512.0
# 12  2010            NaN
# 13  2011      9007202.0
# 14  2012      9160270.0
# 15  2013  8721127.13184
# 16  2014      8762260.0

# %%
new_concat_df = first_indicator_Country

for i in range(len(Indicators)):
  indicator_china = pd.DataFrame()
  indicator, title = columnwise_data(Indicators[i])

  # Displaying the dataframe obtained
  indicator_Country = indicator[['Year','United States']]
  indicator_Country.rename(columns = {'United States':Indicators[i]}, inplace=True)

  # NOw merging it with the previous dataframe
  new_concat_df = pd.merge(new_concat_df,indicator_Country, how = "outer" )

# Displaying the merged df
new_concat_df

# we get a datframe which is unsorted, so we sort it according to year
new_concat_df.sort_values('Year', inplace = True)

# as the previous index becomes unacceptable we reset index
new_concat_df.reset_index(inplace=True)

# now we drop the extra colum of index from our dataframe
new_concat_df.drop(['index', 'Year'], axis=1, inplace = True)

# time to fill NaN value, we will apply ffill and bfill to fill up values obtained through columwise_data()
new_concat_df.fillna(method = "ffill", inplace = True)
new_concat_df.fillna(method = "bfill", inplace = True)

# Datframe after these changes is
new_concat_df
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#        UIS.E.0.T  SE.PRM.ENRL  SE.SEC.ENRL  SE.TER.ENRL      UIS.E.4  \
# 0   7.183122e+06   22037000.0   20593000.0    8498117.0  1643104.000
# 1   7.183122e+06   22037000.0   20593000.0    8498117.0  1643104.000
# 2   7.183122e+06   21676000.0   21161000.0    8948645.0  1643104.000
# 3   7.183122e+06   21873000.0   21161000.0    9297787.0  1643104.000
# 4   7.183122e+06   21201000.0   21591000.0    9602123.0  1643104.000
# 5   7.183122e+06   20613000.0   21656000.0   10223729.0  1643104.000
# 6   7.183122e+06   20213000.0   21680000.0   11184859.0  1643104.000
# 7   7.183122e+06   19825000.0   21619000.0   11012137.0  1643104.000
# ...

# %%
# Now our dataframe is ready, and we can no w plot heatmap
# but before plotting we may delete the NaN column
new_concat_df.dropna(how = "all", axis = 1, inplace = True)
sns.heatmap(new_concat_df, cbar= False, linewidths = .2, linecolor = 'white', annot = True)
sns.set(rc = {'figure.figsize':(20, 20)})

# %%
sns.heatmap(new_concat_df.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This heatmap shows the relation between all these indicators.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above correlation graph we can see that enrollment in school does not positively affect the learning outcomes which emphasise that schooling is not equivalent to learning.
#
# We also see that enrollment in post-secondary, non-tertiary is positively related to learning outcomes, which means encouraging post-secondary non-tertiary courses among students result in necessary skill building which results in better learning outcomes.
#
# We see a positive correlation between govt expenditure and learning outcomes which was expected as more the govt spends on education the more better results we get.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Providing Scholarships to students to encourage them to pursue higher education.
#
# 2. Increasing govt expenditure on policies and schemes to enhance the education sector.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
